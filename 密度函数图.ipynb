# %%
data = {
    '单一轨交': 46.31,
    '单一公交': 24.48,
    '公交→公交': 8.92,
    '轨交→公交': 6.78,
    '公交→轨交': 6.44,
    '公交→公交→公交': 1.37,
    '公交→轨交→公交': 0.92,
    '公交→公交→公交→公交': 0.64,
    '其他': 4.12
}

# %%
data_key = list(data.keys())
data_value = list(data.values())
print(data_key)
print(data_value)
# Out:
# ['单一轨交', '单一公交', '公交→公交', '轨交→公交', '公交→轨交', '公交→公交→公交', '公交→轨交→公交', '公交→轨交→公交→公交', '其他']
# [46.31, 24.48, 8.92, 6.78, 6.44, 1.37, 0.92, 0.64, 4.12]

# %%
import matplotlib.pyplot as plt
# from pylab import *
# mpl.rcParams['font.sans-serif'] = ['SimHei']

# %%
data_1 = []
data_1 = data_1 + [1] * 4631
data_1 = data_1 + [2] * 2448
data_1 = data_1 + [3] * 892
data_1 = data_1 + [4] * 678
data_1 = data_1 + [5] * 644
data_1 = data_1 + [6] * 137
data_1 = data_1 + [7] * 92
data_1 = data_1 + [8] * 64
data_1 = data_1 + [9] * 412

# %%
import numpy as np
import matplotlib.pyplot as plt
import scipy.stats as stats
import matplotlib.style as style
matplotlib.rcParams['font.sans-serif'] = ['SimHei']  # 用黑体显示中文

# %%
# Data
x = list(range(1, 10))
data_1 = data_value
# data_value = data_value
# data_2 = [4631, 7079,7971,8649,9293,9430,9522,9586,10000]
data_2 = [46.31, 70.79,79.71,86.49,92.93,94.30,95.22,95.86,100.00]

# %% [markdown]
# 参考网址：https://blog.csdn.net/weixin_45459224/article/details/100177163

# %%
fig =plt.figure(figsize=(8,6))
plt.bar(x=x, height=data_1, label='Travel Mode', color='blue', alpha=0.8);
plt.plot(x, data_2, 'r', marker='*', label = 'Lei Ji Mi Du');

for x1, yy in zip(x, data_1):
    plt.text(x1, yy + 2, str(yy), ha='center', va='bottom', fontsize=14, rotation=0)
    
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.legend(fontsize=16);

plt.savefig('density.png', dpi=300)
# Out:
# findfont: Font family ['sans-serif'] not found. Falling back to DejaVu Sans.

# %%
# plt.plot(list(range(1, 10)), data_2);
plt.plot(list(range(1, 10)), data_2, 'r', marker='*');
# plt.fill_between(list(range(1, 10)), data_2, alpha=.15)
# plt.plot(np.linspace(1,9,9),stats.norm.pdf(data_2))

# %%
stats.norm.pdf()
# Out:
# array([1.33830226e-04, 3.15601632e-03, 3.37736510e-02, 1.64010075e-01,
#        3.61423830e-01, 3.61423830e-01, 1.64010075e-01, 3.37736510e-02,
#        3.15601632e-03, 1.33830226e-04])

# %%
plt.plot(np.linspace(-4,4,100),stats.norm.pdf(np.linspace(-4,4,100))) #从（-4，4）中随机选取100个数，绘制该事件的概率密度函数

plt.fill_between(np.linspace(-4,4,100),stats.norm.pdf(np.linspace(-4,4,100)),alpha=.15)#对曲线内部进行填充
